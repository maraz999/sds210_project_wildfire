# %%
# Where are the most intense wildfires in Madagascar, and does the brightness temperature difference (Ti4 − Ti5) 
#reveal spatial patterns in fire behavior?

# %%
# API Key : not pushed to GitHub (notebooks/ is in .gitignore)
map_key = "dc38faa964bb2d75d020b913a3579aa3"

# %%
import requests
import pandas as pd
import time
import geopandas as gpd
import matplotlib.pyplot as plt
import os
import matplotlib.patches as mpatches
import numpy as np
import folium
from folium.plugins import (
    MarkerCluster,
    HeatMap,
    TimestampedGeoJson
)
import branca.colormap as cm

# %%
url_api = f"https://firms.modaps.eosdis.nasa.gov/api/area/csv/{map_key}/VIIRS_SNPP_NRT/world/2"

response = requests.get(url_api)
print(response.status_code)
print(response.text[:200]) 
    
fires_df = pd.read_csv(url_api)
# Out:
# 200
# latitude,longitude,bright_ti4,scan,track,acq_date,acq_time,satellite,instrument,confidence,version,bright_ti5,frp,daynight
# 64.79336,-147.60695,333.56,0.57,0.69,2026-05-16,1,N,VIIRS,n,2.0NRT,289.18,5.2

# %%
fires_df.head()
# Out:
#    latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0  64.79336 -147.60695      333.56  0.57   0.69  2026-05-16         1
# 1  64.79538 -147.61407      329.85  0.57   0.69  2026-05-16         1
# 2  64.80796 -147.59891      327.95  0.57   0.69  2026-05-16         1
# 3  58.81335   49.17291      305.72  0.54   0.51  2026-05-16        13
# 4  64.64723   24.42758      309.43  0.45   0.47  2026-05-16        13
#
#   satellite instrument confidence version  bright_ti5   frp daynight
# 0         N      VIIRS          n  2.0NRT      289.18  5.28        D
# 1         N      VIIRS          n  2.0NRT      288.63  3.78        D
# 2         N      VIIRS          n  2.0NRT      288.91  4.37        D
# 3         N      VIIRS          n  2.0NRT      281.96  1.43        N
# 4         N      VIIRS          n  2.0NRT      267.02  2.10        N

# %%
fires_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33359 entries, 0 to 33358
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   latitude    33359 non-null  float64
#  1   longitude   33359 non-null  float64
#  2   bright_ti4  33359 non-null  float64
#  3   scan        33359 non-null  float64
#  4   track       33359 non-null  float64
#  5   acq_date    33359 non-null  object
#  6   acq_time    33359 non-null  int64
#  7   satellite   33359 non-null  object
#  8   instrument  33359 non-null  object
#  9   confidence  33359 non-null  object
#  10  version     33359 non-null  object
#  11  bright_ti5  33359 non-null  float64
#  12  frp         33359 non-null  float64
#  13  daynight    33359 non-null  object
# dtypes: float64(7), int64(1), object(6)
# memory usage: 3.6+ MB

# %%
#Ti5 = the air temperature around you 
#Ti4 = the temperature of the actual flame 
#temp_diff = Ti4 - Ti5 showing How much hotter the fire is compared to its surroundings

# %%
fires_df.isnull().sum()
# Out:
# latitude      0
# longitude     0
# bright_ti4    0
# scan          0
# track         0
# acq_date      0
# acq_time      0
# satellite     0
# instrument    0
# confidence    0
# version       0
# bright_ti5    0
# frp           0
# daynight      0
# dtype: int64

# %%
fires_gdf = gpd.GeoDataFrame(
    fires_df,
    geometry=gpd.points_from_xy(fires_df['longitude'], fires_df['latitude']),
    crs='EPSG:4326')

## load world and subset just africa
os.getcwd() #prints current working directory
os.listdir("../data") # ... = go up one folder
os.listdir("../data/ne_110m_admin_0_countries")

os.listdir("../data/ne_10m_admin_0_countries") #better !!! 
    #fires near the coast might get clipped out because the polygon doesn't perfectly hug the coastline so with 10 m higher resolution

world_110 = gpd.read_file("../data/ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp") 

world = gpd.read_file("../data/ne_10m_admin_0_countries/ne_10m_admin_0_countries.shp")
madagascar = world[world["NAME"] == "Madagascar"]

#spatial join: filters detections to Africa only and attaches country name to each fire point based on geographic location
fires_madagascar = gpd.sjoin(
    fires_gdf,
    madagascar[["geometry", "NAME"]],
    how="inner", #only matching points are kept that are in African polygon 
    predicate="within") #point must be fully inside the polygon

# %%
print(fires_madagascar.head())
print(f"\nTotal number of fires: {len(fires_madagascar)}")
# Out:
#        latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 10538 -24.03913   46.40337      335.23  0.74   0.76  2026-05-16       943
# 10539 -24.03865   46.41140      335.93  0.74   0.76  2026-05-16       943
# 10540 -23.84234   46.59678      333.08  0.72   0.76  2026-05-16       943
# 10541 -23.27832   46.28130      331.11  0.75   0.77  2026-05-16       943
# 10542 -23.00048   45.91246      332.50  0.78   0.78  2026-05-16       943
#
#       satellite instrument confidence version  bright_ti5    frp daynight  \
# 10538         N      VIIRS          n  2.0NRT      299.81   5.45        D
# 10539         N      VIIRS          n  2.0NRT      299.77  13.51        D
# 10540         N      VIIRS          n  2.0NRT      293.52   4.43        D
# 10541         N      VIIRS          n  2.0NRT      297.52   6.50        D
# 10542         N      VIIRS          n  2.0NRT      299.67   4.52        D
#
#                          geometry  index_right        NAME
# 10538  POINT (46.40337 -24.03913)          181  Madagascar
# 10539   POINT (46.4114 -24.03865)          181  Madagascar
# 10540  POINT (46.59678 -23.84234)          181  Madagascar
# 10541   POINT (46.2813 -23.27832)          181  Madagascar
# 10542  POINT (45.91246 -23.00048)          181  Madagascar
#
# Total number of fires: 1037

# %%
#Check what confidence values exist
print(fires_madagascar['confidence'].unique())
# Out:
# ['n' 'h' 'l']

# %%
# create new variable-> difference of the brighntesses
fires_madagascar["temp_diff"] = fires_madagascar["bright_ti4"]-fires_madagascar["bright_ti5"]

# %%
fires_madagascar["acq_time"] = fires_madagascar["acq_time"].astype(str).str.zfill(4) #zfill: HHMM->"0930", "0054"

fires_madagascar["datetime"] = pd.to_datetime( # needs string to work : above converted acq_time to strimg
    fires_madagascar['acq_date'] + ' ' + #' ' = space -> besseren überblick
    fires_madagascar["acq_time"].str[:2] + ':' + #hours divided after by :
    fires_madagascar["acq_time"].str[2:], # minutes
    format="%Y-%m-%d %H:%M")

# %%
fires_madagascar = fires_madagascar[["latitude", 
                             "longitude",
                             "temp_diff",                             
                             "bright_ti4",
                             "bright_ti5",        
                             "frp", 
                             "daynight",
                             "datetime"]]
fires_madagascar.head()
# Out:
#        latitude  longitude  temp_diff  bright_ti4  bright_ti5    frp daynight  \
# 10538 -24.03913   46.40337      35.42      335.23      299.81   5.45        D
# 10539 -24.03865   46.41140      36.16      335.93      299.77  13.51        D
# 10540 -23.84234   46.59678      39.56      333.08      293.52   4.43        D
# 10541 -23.27832   46.28130      33.59      331.11      297.52   6.50        D
# 10542 -23.00048   45.91246      32.83      332.50      299.67   4.52        D
#
#                  datetime
# 10538 2026-05-16 09:43:00
# 10539 2026-05-16 09:43:00
# 10540 2026-05-16 09:43:00
# 10541 2026-05-16 09:43:00
# 10542 2026-05-16 09:43:00

# %%
fires_madagascar = gpd.GeoDataFrame(
    fires_madagascar,
    geometry=gpd.points_from_xy(fires_madagascar['longitude'], fires_madagascar['latitude']),
    crs='EPSG:4326')

fires_madagascar.explore(
    column="frp",
    cmap="hot",
    tooltip=[
        "datetime",
        "frp",
        "temp_diff"
    ]
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be5dbcb80bcfb00d2d902cf5bf962da0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be5dbcb80bcfb00d2d902cf5bf962da0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be5dbcb80bcfb00d2d902cf5bf962da0 = L.map(
#                 &quot;map_be5dbcb80bcfb00d2d902cf5bf962da0&quot;,
#                 {
#                     center: [-18.67376, 46.519994999999994],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_be5dbcb80bcfb00d2d902cf5bf962da0);
#
#
#
#
#
#             var tile_layer_013b87bdc6f4a66f76cb7790fb4c2b13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_013b87bdc6f4a66f76cb7790fb4c2b13.addTo(map_be5dbcb80bcfb00d2d902cf5bf962da0);
#
#
#             map_be5dbcb80bcfb00d2d902cf5bf962da0.fitBounds(
#                 [[-24.99577, 43.70457], [-12.35175, 49.33542]],
#                 {}
#             );
#
#
#         function geo_json_649c0fa0b7b68db1cdeb7be3fc06ee37_styler(feature) {
#             switch(feature.id) {
#                 case &quot;10538&quot;: case &quot;10570&quot;: case &quot;10609&quot;: case &quot;10646&quot;: case &quot;10724&quot;: case &quot;11310&quot;: case &quot;11337&quot;: case &quot;11344&quot;: case &quot;11412&quot;: case &quot;11458&quot;: case &quot;11472&quot;: case &quot;11569&quot;: case &quot;11589&quot;: case &quot;11618&quot;: case &quot;11765&quot;: case &quot;11891&quot;: case &quot;11894&quot;:
#                     return {&quot;color&quot;: &quot;#6c0000&quot;, &quot;fillColor&quot;: &quot;#6c0000&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10539&quot;: case &quot;10619&quot;: case &quot;10620&quot;: case &quot;11852&quot;:
#                     return {&quot;color&quot;: &quot;#ff0a00&quot;, &quot;fillColor&quot;: &quot;#ff0a00&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10540&quot;: case &quot;10542&quot;: case &quot;10567&quot;: case &quot;10725&quot;: case &quot;11274&quot;: case &quot;11288&quot;: case &quot;11304&quot;: case &quot;11322&quot;: case &quot;11417&quot;: case &quot;11439&quot;: case &quot;11440&quot;: case &quot;11506&quot;: case &quot;11513&quot;: case &quot;11553&quot;: case &quot;11631&quot;: case &quot;11642&quot;:
#                     return {&quot;color&quot;: &quot;#590000&quot;, &quot;fillColor&quot;: &quot;#590000&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10541&quot;: case &quot;10551&quot;: case &quot;10582&quot;: case &quot;10632&quot;: case &quot;10706&quot;: case &quot;10731&quot;: case &quot;10732&quot;: case &quot;10733&quot;: case &quot;11186&quot;: case &quot;11332&quot;: case &quot;11351&quot;: case &quot;11352&quot;: case &quot;11427&quot;: case &quot;11428&quot;: case &quot;11539&quot;: case &quot;11562&quot;: case &quot;11757&quot;: case &quot;11759&quot;: case &quot;11760&quot;: case &quot;11776&quot;: case &quot;11777&quot;: case &quot;11885&quot;:
#                     return {&quot;color&quot;: &quot;#810000&quot;, &quot;fillColor&quot;: &quot;#810000&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10543&quot;: case &quot;10599&quot;: case &quot;10602&quot;: case &quot;10622&quot;: case &quot;11184&quot;: case &quot;11243&quot;: case &quot;11248&quot;: case &quot;11267&quot;: case &quot;11433&quot;: case &quot;11437&quot;: case &quot;11699&quot;: case &quot;11718&quot;: case &quot;11722&quot;: case &quot;11746&quot;: case &quot;11813&quot;: case &quot;11834&quot;: case &quot;11835&quot;: case &quot;12090&quot;:
#                     return {&quot;color&quot;: &quot;#610000&quot;, &quot;fillColor&quot;: &quot;#610000&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10544&quot;: case &quot;10562&quot;:
#                     return {&quot;

# %%
print("FRP")
print(fires_madagascar['frp'].describe())

print("\nTemperature Difference (Ti4 - Ti5)")
print(fires_madagascar['temp_diff'].describe())
# Out:
# FRP
# count    1037.000000
# mean        6.265728
# std         4.342972
# min         0.380000
# 25%         3.420000
# 50%         5.150000
# 75%         7.610000
# max        34.700000
# Name: frp, dtype: float64
#
# Temperature Difference (Ti4 - Ti5)
# count    1037.000000
# mean       40.721167
# std        10.982300
# min        10.550000
# 25%        33.570000
# 50%        37.960000
# 75%        45.980000
# max        72.500000
# Name: temp_diff, dtype: float64

# %%
#Correlation between FRP and temp_diff
#if Ti4-Ti5 is a good proxy for intensity, it should correlate with FRP

correlation = fires_madagascar['frp'].corr(fires_madagascar['temp_diff'])
print(f"Correlation between FRP and temp_diff: {correlation:.2f}")

#cor: 0.61  is not very high but shows that the 2 variable mostly agree but not completely 
    # when same : it is an intense fire
    # not same could mean: fire hot relative to sorrounding -> high temp_diff but low frp 
        # oder vice versa
# Out:
# Correlation between FRP and temp_diff: 0.61

# %%
# Madagascar is a long island-> split it at its geographic middle latitude
# to see if fires behave differently in the north vs south
mid_lat = fires_madagascar['latitude'].median()

fires_madagascar['region'] = fires_madagascar['latitude'].apply(
    lambda x: 'North' if x > mid_lat else 'South'
)

# Compare intensity between north and south
region_stats = fires_madagascar.groupby('region')[['frp', 'temp_diff']].mean()
print(region_stats)
# Out:
#              frp  temp_diff
# region
# North   6.955212  41.587954
# South   5.577572  39.856050

# %%
#why N/S: Mad. has very different ecosystems north vs south
#north is tropical/humid, the south is dry/semi-arid. Fires might behave very differently depending on vegetation and climate. 
#This is the geographic pattern your research question asks about.

# %%
##histogramm
fig, axes = plt.subplots(1, 2, figsize =( 12, 4))

#distribution frp
axes[0].hist(fires_madagascar['frp'], bins = 30, color = 'coral', edgecolor = 'black')
axes[0].set_title('Distribution FRP')
axes[0].set_xlabel('FRP MW')
axes[0].set_ylabel('count')

#distribution temp_diff
axes[1].hist(fires_madagascar['temp_diff'], bins = 30, color = 'Cornflowerblue', edgecolor = 'black')
axes[1].set_title('Distribution of ti4 - ti5')
axes[1].set_xlabel('Temperature difference K')
axes[1].set_ylabel('count')

plt.suptitle('Wildfire Intensity Distributions in Madagascar', fontsize=13)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize =( 12, 4))

region_stats['frp'].plot(kind = 'bar', ax= axes[0], color = ['Cornflowerblue', 'coral'], edgecolor = 'black')
axes[0].set_title('Avg FRP by region North or South')
axes[0].set_xlabel('')
axes[0].set_ylabel('mean FRP')
axes[0].tick_params(axis="x", rotation=45)

region_stats['temp_diff'].plot(kind = 'bar', ax= axes[1], color = ['Cornflowerblue', 'coral'], edgecolor = 'black')
axes[1].set_title('Avg temperature difference by region')
axes[1].set_xlabel('')
axes[1].set_ylabel('mean ti4 - ti5 K')
axes[1].tick_params(axis="x", rotation=45)

# %%
#to get the center of Madagas.
center = madagascar.geometry.centroid.iloc[0]
center_lat = center.y
center_lon = center.x 

#!!!! wrong  need meters not degrees
# Out:
# /var/folders/6l/h3f5hx216rs7vzxx_c82k8100000gn/T/ipykernel_97485/558366807.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = madagascar.geometry.centroid.iloc[0]

# %%
madagascar_projected= madagascar.to_crs(epsg=32738)
center_projected= madagascar_projected.geometry.centroid.iloc[0]

center = gpd.GeoSeries([center_projected], crs=32738).to_crs(epsg=4326).iloc[0]
center_lat = center.y
center_lon = center.x 
print(center_lat, center_lon)
# Out:
# -19.314007703204048 46.74456026925646

# %%
#basemap
m = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=6,
    tiles="Esri.WorldImagery" # satellite basemap to shows real landscape: veg./terrain
)

#colormap as base temp_differece
td_colormap = cm.LinearColormap(
    colors = ['LightYellow', 'DarkOrange', 'FireBrick'],
    vmin = fires_madagascar['temp_diff'].quantile(0.05),
    vmax = fires_madagascar['temp_diff'].quantile(0.95))

frp_min = fires_madagascar['frp'].quantile(0.05)
frp_max = fires_madagascar['frp'].quantile(0.95) 

# 1. layer
# SIZE : how intense the fire is (FRP in MW)
# COLOR: how much hotter than surroundings (Ti4 - Ti5 in K)
fg_main = folium.FeatureGroup(name = "Intensity (size=FRP, color=temp_diff)", show=True)

for _, row in fires_madagascar.iterrows():
    folium.CircleMarker(
        location= [row['latitude'], row['longitude']],
        r = 3+ (row['frp'] / fires_madagascar['frp'].max()) *12 ,
        fill_color = td_colormap(row['temp_diff']),
        #give me the color that corresponds to the specific fire temp_diff value
        fill_opacity = 0.75,
        fill = True,
        color = 'black',
        weight = 0.25,
        #border : black but with thin lines
        tooltip = f"FRP: {row['frp']:.1f} (MV) | ΔT: {row['temp_diff']:.1f} (K)",
        popup = folium.Popup(
            f"FRP: {row['frp']:.1f} (MV)<br>"
            f"Temp. difference:</br>{row['temp_diff']:.1f} (K)<br>"
            f"Region:</br>{row['region']}"
        )
    ).add_to(fg_main)

td_colormap.add_to(m)
fg_main.add_to(m)


# 2. laver Heatmap
fg_heat = folium.FeatureGroup(name= "Fire density heatmap", show = False)
HeatMap(
    fires_madagascar[['latitude', 'longitude', 'frp']].values.tolist(),
    min_opacity = 0.4,
    radius = 13,
    blur = 9
).add_to(fg_heat)

fg_heat.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d48facc4c609f4c1ca0448873193dc56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d48facc4c609f4c1ca0448873193dc56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d48facc4c609f4c1ca0448873193dc56 = L.map(
#                 &quot;map_d48facc4c609f4c1ca0448873193dc56&quot;,
#                 {
#                     center: [-19.314007703204048, 46.74456026925646],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f79ed3e863b2e59146dfef9a43ef1374 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f79ed3e863b2e59146dfef9a43ef1374.addTo(map_d48facc4c609f4c1ca0448873193dc56);
#
#
#     var color_map_b137453772fda3fe59a0e7b86a6a12f6 = {};
#
#
#     color_map_b137453772fda3fe59a0e7b86a6a12f6.color = d3.scale.threshold()
#               .domain([27.998, 28.071098196392786, 28.144196392785574, 28.21729458917836, 28.290392785571143, 28.363490981963928, 28.436589178356716, 28.5096873747495, 28.582785571142285, 28.655883767535073, 28.728981963927858, 28.802080160320642, 28.875178356713427, 28.948276553106215, 29.021374749499, 29.094472945891784, 29.167571142284572, 29.240669338677357, 29.31376753507014, 29.386865731462926, 29.459963927855714, 29.5330621242485, 29.606160320641283, 29.67925851703407, 29.752356713426856, 29.82545490981964, 29.898553106212425, 29.971651302605213, 30.044749498997998, 30.117847695390783, 30.19094589178357, 30.264044088176355, 30.33714228456914, 30.410240480961924, 30.483338677354713, 30.556436873747497, 30.62953507014028, 30.70263326653307, 30.775731462925854, 30.84882965931864, 30.921927855711424, 30.995026052104212, 31.068124248496996, 31.14122244488978, 31.21432064128257, 31.287418837675354, 31.36051703406814, 31.433615230460923, 31.50671342685371, 31.579811623246496, 31.65290981963928, 31.72600801603207, 31.799106212424853, 31.872204408817637, 31.945302605210422, 32.01840080160321, 32.091498997996, 32.16459719438878, 32.23769539078157, 32.31079358717435, 32.38389178356714, 32.45698997995992, 32.530088176352706, 32.60318637274549, 32.67628456913828, 32.74938276553107, 32.82248096192385, 32.895579158316636, 32.96867735470942, 33.041775551102205, 33.114873747495, 33.187971943887774, 33.261070140280566, 33.33416833667335, 33.407266533066135, 33.48036472945892, 33.553462925851704, 33.62656112224449, 33.69965931863728, 33.772757515030065, 33.84585571142285, 33.918953907815634, 33.99205210420842, 34.0651503006012, 34.138248496993995, 34.21134669338677, 34.284444889779564, 34.35754308617235, 34.430641282565134, 34.50373947895792, 34.5768376753507, 34.64993587174349, 34.72303406813628, 34.796132264529064, 34.86923046092185, 34.94232865731463, 35.01542685370742, 35.0885250501002, 35.161623246492994, 35.23472144288577, 35.30781963927856, 35.38091783567135, 35.45401603206413, 35.52711422845692, 35.6002124248497, 35.673310621242486, 35.74640881763528, 35.81950701402806, 35.89260521042085, 35.96570340681363, 36.038801603206416, 36.1118997995992, 36.18499799599199, 36.25809619238477, 36.33119438877756, 36.404292585170346, 36.47739078156313, 36.550488977955915, 36.6235871743487, 36.696685370741484, 36.76978356713427, 36.84288176352706, 36.915979959919845, 36.98907815631263, 37.062176352705414, 37.1352745490982, 37.20837274549098, 37.281470941883775, 37.35456913827656, 37.427667334669344, 37.50076553106213, 37.57386372745491, 37.6469619238477, 37.72006012024049, 37.79315831663327, 37.86625651302606, 37.93935470941884, 38.01245290581163, 38.08555110220441, 38.1586492985972, 38.23174749498999, 38.304845691382766, 38.37794388777556, 38.45104208416834, 38.52414028056113, 38.59723847695391, 38.670336673346696, 38.74343486973948, 38.816533066132266, 38.88963126252506, 38.96272945891784, 39.03582765531063, 39.10892585170341, 39.182024048096196, 39.25512224448898, 39.32822044088177, 39.40131863727456, 39.47441683366734, 39.547515030060126, 39.62061322645291, 39.693711422845695, 39.76680961923849, 39.839907815631264, 39.913006012024056, 39.98610420841684, 40.059202404809625, 40.13230060120241, 40.205398797595194, 40.278496993987986, 40.35159519038076, 40.424693386773555, 40.49779158316634, 40.570889779559124, 40.64398797595191, 40.71708617234469,
