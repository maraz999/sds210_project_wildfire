# %%
#Do African wildfires detected at night show higher brightness I4 temperatures and FRP than daytime detections,
    #and is there a spatial pattern to this difference across Africa?

# %%
import requests
import pandas as pd
import time
import geopandas as gpd
import matplotlib.pyplot as plt
import os
import matplotlib.patches as mpatches
import numpy as np

# %%
##made map_key -> .env file

# %%
url_api = "https://firms.modaps.eosdis.nasa.gov/api/area/csv/dc38faa964bb2d75d020b913a3579aa3/VIIRS_SNPP_NRT/world/5"
# key separat verwaltten? wie -> variable spezifizieren mein key: f string,   .env-> googlen recherchiere
response = requests.get(url_api)
print(response.status_code)
print(response.text[:200]) 

fires_df = pd.read_csv(url_api)
fires_df.info()
fires_df.head()
#give me something
