# %%
map_key = "dc38faa964bb2d75d020b913a3579aa3"

# %%
import sys
import os
import geopandas as gpd

sys.path.append(os.path.abspath('..'))

from wildfire_utils import fetch_data, prepare_fires, region_analysis, build_map

world = gpd.read_file('../data/ne_10m_admin_0_countries/ne_10m_admin_0_countries.shp')
madagascar = world[world['NAME'] == 'Madagascar']

fires_gdf = fetch_data(map_key)

fires_madagascar= prepare_fires(fires_gdf, madagascar)

region_stats = region_analysis(fires_madagascar)
# Out:
# 200
#
# latitude,longitude,bright_ti4,scan,track,acq_date,acq_time,satellite,instrument,confidence,version,bright_ti5,frp,daynight
# -21.3751,17.7158,297.99,0.41,0.37,2026-05-18,1,N,VIIRS,n,2.0NRT,281.6,0.06,N
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31824 entries, 0 to 31823
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   latitude    31824 non-null  float64
#  1   longitude   31824 non-null  float64
#  2   bright_ti4  31824 non-null  float64
#  3   scan        31824 non-null  float64
#  4   track       31824 non-null  float64
#  5   acq_date    31824 non-null  object
#  6   acq_time    31824 non-null  int64
#  7   satellite   31824 non-null  object
#  8   instrument  31824 non-null  object
#  9   confidence  31824 non-null  object
#  10  version     31824 non-null  object
#  11  bright_ti5  31824 non-null  float64
#  12  frp         31824 non-null  float64
#  13  daynight    31824 non-null  object
# dtypes: float64(7), int64(1), object(6)
# memory usage: 3.4+ MB
# None
#
#    latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0 -21.37510   17.71580      297.99  0.41   0.37  2026-05-18         1
# 1 -19.32708   16.25864      303.75  0.50   0.41  2026-05-18         1
# 2 -19.32333   16.25940      300.06  0.50   0.41  2026-05-18         1
# 3 -19.31634   16.28538      307.12  0.50   0.41  2026-05-18         1
# 4 -19.31549   16.28064      304.25  0.50   0.41  2026-05-18         1
#
#   satellite instrument confidence version  bright_ti5   frp daynight
# 0         N      VIIRS          n  2.0NRT      281.60  0.06        N
# 1         N      VIIRS          n  2.0NRT      287.27  1.30        N
# 2         N      VIIRS          n  2.0NRT      286.70  1.25        N
# 3         N      VIIRS          n  2.0NRT      287.03  1.24        N
# 4         N      VIIRS          n  2.0NRT      287.06  0.92        N
#
# latitude       0
# longitude      0
# bright_ti4     0
# scan           0
# track          0
# acq_date       0
# acq_time       0
# satellite      0
# instrument     0
# confidence     0
# version        0
# bright_ti5     0
# frp            0
# daynight       0
# geometry       0
# index_right    0
# NAME           0
# dtype: int64
# Fires within Madagascar: 909 detections.
#
# Correlation btw FRP and temp_diff: 0.3105616010052916
#
#              frp  temp_diff
# region
# North   5.279780  33.646498
# South   5.090418  32.819363
